# %%
from TrajectoryUtils import *
import numpy as np
import matplotlib.pyplot as plt

# %%
pds = []
for i in range(100):
    pd, vd = goto(i, 100, np.array([0.34123012, 0.59830834,0.03749224]).reshape((3, 1)), np.array([0.0,0.0,.90]).reshape((3, 1)))
    pds.append(pd[:, 0])
plt.plot(pds)

# %%
pd, vd = goto(6, 100, np.array([0.34123012, 0.59830834,0.03749224]).reshape((3, 1)), np.array([0.0,0.0,.90]).reshape((3, 1)))

# %%
pd
# Out:
# array([[0.33769225],
#        [0.59210508],
#        [0.04643472]])
